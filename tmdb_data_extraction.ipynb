# %%
import requests
import pandas as pd
from datetime import datetime
import time

# Your TMDB API key
API_KEY = "2ea4941ed01886e1416c4f99347c48e1"

def discover_movies(year, pages=10):
    """Get movie IDs for a given year (max 500 pages)"""
    ids = []
    for page in range(1, pages+1):
        url = f"https://api.themoviedb.org/3/discover/movie"
        params = {
            "api_key": API_KEY,
            "language": "en-US",
            "primary_release_year": year,
            "page": page
        }
        r = requests.get(url, params=params).json()
        ids.extend([m["id"] for m in r.get("results", [])])
    return ids

# %%
def get_movie_full(movie_id):
    url = f"https://api.themoviedb.org/3/movie/{movie_id}"
    params = {
        "api_key": API_KEY,
        "language": "en-US",
        "append_to_response": "credits"
    }
    r = requests.get(url, params=params).json()
    
    # Extract director
    director = None
    for crew in r["credits"].get("crew", []):
        if crew.get("job") == "Director":
            director = crew["name"]
            break
    
    # Extract top 3 cast
    cast_names = [c["name"] for c in r["credits"].get("cast", [])[:3]]
    while len(cast_names) < 3:
        cast_names.append(None)
    
    return {
        "id": r.get("id"),
        "title": r.get("title"),
        "date_string": r.get("release_date"),
        "language": r.get("original_language"),
        "genre": ",".join(str(g["id"]) for g in r.get("genres", [])),
        "duration": r.get("runtime"),
        "rating": r.get("vote_average"),
        "rating_count": r.get("vote_count"),
        "cast1": cast_names[0],
        "cast2": cast_names[1],
        "cast3": cast_names[2],
        "director": director,
        "budget": r.get("budget"),
        "box_office": r.get("revenue"),
        "spoken_languages": ",".join(l["english_name"] for l in r.get("spoken_languages", []))
    }

# %%
def collect_all_years(start_year=1900, end_year=None, pages=10):
    if end_year is None:
        end_year = datetime.now().year
    
    all_movies = []  # collect all years here
    
    for year in range(start_year, end_year+1):
        print(f"Collecting {year} ...")
        ids = discover_movies(year, pages=pages)
        
        for mid in ids:
            try:
                details = get_movie_full(mid)
                all_movies.append(details)   # append to master list
            except Exception as e:
                print("Error on", mid, e)
            time.sleep(0.25)  # avoid hitting rate limit
        
        print(f"Finished {year} ({len(all_movies)} movies total so far)")
    
    # convert once at the end
    df = pd.DataFrame(all_movies)
    df.to_csv("tmdb_all_movies.csv", index=False)
    print(f"Saved {len(df)} movies from {start_year}–{end_year}")
    return df

# %%
if __name__ == "__main__":
    collect_all_years(start_year=1900, pages=10)
# Out:
# Collecting 1900 ...
# Finished 1900 (200 movies total so far)
# Collecting 1901 ...
# Finished 1901 (400 movies total so far)
# Collecting 1902 ...
# Finished 1902 (600 movies total so far)
# Collecting 1903 ...
# Finished 1903 (800 movies total so far)
# Collecting 1904 ...
# Finished 1904 (1000 movies total so far)
# Collecting 1905 ...
# Finished 1905 (1200 movies total so far)
# Collecting 1906 ...
# Finished 1906 (1400 movies total so far)
# Collecting 1907 ...
# Finished 1907 (1600 movies total so far)
# Collecting 1908 ...
# Finished 1908 (1800 movies total so far)
# Collecting 1909 ...
# Finished 1909 (2000 movies total so far)
# Collecting 1910 ...
# Finished 1910 (2200 movies total so far)
# Collecting 1911 ...
# Finished 1911 (2400 movies total so far)
# Collecting 1912 ...
# Finished 1912 (2600 movies total so far)
# Collecting 1913 ...
# Finished 1913 (2800 movies total so far)
# Collecting 1914 ...
# Finished 1914 (3000 movies total so far)
# Collecting 1915 ...
# Finished 1915 (3200 movies total so far)
# Collecting 1916 ...
# Finished 1916 (3400 movies total so far)
# Collecting 1917 ...
# Finished 1917 (3600 movies total so far)
# Collecting 1918 ...
# Finished 1918 (3800 movies total so far)
# Collecting 1919 ...
# Finished 1919 (4000 movies total so far)
# Collecting 1920 ...
# Finished 1920 (4200 movies total so far)
# Collecting 1921 ...
# Finished 1921 (4400 movies total so far)
# Collecting 1922 ...
# Finished 1922 (4600 movies total so far)
# Collecting 1923 ...
# Finished 1923 (4800 movies total so far)
# Collecting 1924 ...
# Finished 1924 (5000 movies total so far)
# Collecting 1925 ...
# Finished 1925 (5200 movies total so far)
# Collecting 1926 ...
# Finished 1926 (5400 movies total so far)
# Collecting 1927 ...
# Finished 1927 (5600 movies total so far)
# Collecting 1928 ...
# Finished 1928 (5800 movies total so far)
# Collecting 1929 ...
# Finished 1929 (6000 movies total so far)
# Collecting 1930 ...
# Finished 1930 (6200 movies total so far)
# Collecting 1931 ...
# Finished 1931 (6400 movies total so far)
# Collecting 1932 ...
# Finished 1932 (6600 movies total so far)
# Collecting 1933 ...
# Finished 1933 (6800 movies total so far)
# Collecting 1934 ...
# Finished 1934 (7000 movies total so far)
# Collecting 1935 ...
# Finished 1935 (7200 movies total so far)
# Collecting 1936 ...
# Finished 1936 (7400 movies total so far)
# Collecting 1937 ...
# Finished 1937 (7600 movies total so far)
# Collecting 1938 ...
# Finished 1938 (7800 movies total so far)
# Collecting 1939 ...
# Finished 1939 (8000 movies total so far)
# Collecting 1940 ...
# Finished 1940 (8200 movies total so far)
# Collecting 1941 ...
# Finished 1941 (8400 movies total so far)
# Collecting 1942 ...
# Finished 1942 (8600 movies total so far)
# Collecting 1943 ...
# Finished 1943 (8800 movies total so far)
# Collecting 1944 ...
# Finished 1944 (9000 movies total so far)
# Collecting 1945 ...
# Finished 1945 (9200 movies total so far)
# Collecting 1946 ...
# Finished 1946 (9400 movies total so far)
# Collecting 1947 ...
# Finished 1947 (9600 movies total so far)
# Collecting 1948 ...
# Finished 1948 (9800 movies total so far)
# Collecting 1949 ...
# Finished 1949 (10000 movies total so far)
# Collecting 1950 ...
# Finished 1950 (10200 movies total so far)
# Collecting 1951 ...
# Finished 1951 (10400 movies total so far)
# Collecting 1952 ...
# Finished 1952 (10600 movies total so far)
# Collecting 1953 ...
# Finished 1953 (10800 movies total so far)
# Collecting 1954 ...
# Finished 1954 (11000 movies total so far)
# Collecting 1955 ...
# Finished 1955 (11200 movies total so far)
# Collecting 1956 ...
# Finished 1956 (11400 movies total so far)
# Collecting 1957 ...
# Finished 1957 (11600 movies total so far)
# Collecting 1958 ...
# Finished 1958 (11800 movies total so far)
# Collecting 1959 ...
# Finished 1959 (12000 movies total so far)
# Collecting 1960 ...
# Finished 1960 (12200 movies total so far)
# Collecting 1961 ...
# Finished 1961 (12400 movies total so far)
# Collecting 1962 ...
# Finished 1962 (12600 movies total so far)
# Collecting 1963 ...
# Finished 1963 (12800 movies total so far)
# Collecting 1964 ...
# Finished 1964 (13000 movies total so far)
# Collecting 1965 ...
# Finished 1965 (13200 movies total so far)
# Collecting 1966 ...
# Finished 1966 (13400 movies total so far)
# Collecting 1967 ...
# Finished 1967 (13600 movies total so far)
# Collecting 1968 ...
# Finished 1968 (13800 movies total so far)
# Collecting 1969 ...
# Finished 1969 (14000 movies total so far)
# Collecting 1970 ...
# Finished 1970 (14200 movies total so far)
# Collecting 1971 ...
# Finished 1971 (14400 movies total so far)
# Collecting 1972 ...
# Finished 1972 (14600 movies total so far)
# Collecting 1973 ...
# Finished 1973 (14800 movies total so far)
# Collecting 1974 ...
# Finished 1974 (15000 movies total so far)
# Collecting 1975 ...
# Finished 1975 (15200 movies total so far)
# Collecting 1976 ...
# Finished 1976 (15400 movies total so far)
# Collecting 1977 ...
# Finished 1977 (15600 movies total so far)
# Collecting 1978 ...
# Finished 1978 (15800 movies total so far)
# Collecting 1979 ...
# Finished 1979 (16000 movies total so far)
# Collecting 1980 ...
# Finished 1980 (16200 movies total so far)
# Collecting 1981 ...
# Finished 1981 (16400 movies total so far)
# Collecting 1982 ...
# Finished 1982 (16600 movies total so far)
# Collecting 1983 ...
# Finished 1983 (16800 movies total so far)
# Collecting 1984 ...
# Finished 1984 (17000 movies total so far)
# Collecting 1985 ...
# Finished 1985 (17200 movies total so far)
# Collecting 1986 ...
# Finished 1986 (17400 movies total so far)
# Collecting 1987 ...
# Finished 1987 (17600 movies total so far)
# Collecting 1988 ...
# Finished 1988 (17800 movies total so far)
# Collecting 1989 ...
# Finished 1989 (18000 movies total so far)
# Collecting 1990 ...
# Finished 1990 (18200 movies total so far)
# Collecting 1991 ...
# Finished 1991 (18400 movies total so far)
# Collecting 1992 ...
# Finished 1992 (18600 movies total so far)
# Collecting 1993 ...
# Finished 1993 (18800 movies total so far)
# Collecting 1994 ...
# Finished 1994 (19000 movies total so far)
# Collecting 1995 ...
# Finished 1995 (19200 movies total so far)
# Collecting 1996 ...
# Finished 1996 (19400 movies total so far)
# Collecting 1997 ...
# Finished 1997 (19600 movies total so far)
# Collecting 1998 ...
# Finished 1998 (19800 movies total so far)
# Collecting 1999 ...
# Finished 1999 (20000 movies total so far)
# Collecting 2000 ...
# Finished 2000 (20200 movies total so far)
# Collecting 2001 ...
# Finished 2001 (20400 movies total so far)
# Collecting 2002 ...
# Finished 2002 (20600 movies total so far)
# Collecting 2003 ...
# Finished 2003 (20800 movies total so far)
# Collecting 2004 ...
# Finished 2004 (21000 movies total so far)
# Collecting 2005 ...
# Finished 2005 (21200 movies total so far)
# Collecting 2006 ...
# Finished 2006 (21400 movies total so far)
# Collecting 2007 ...
# Finished 2007 (21600 movies total so far)
# Collecting 2008 ...
# Finished 2008 (21800 movies total so far)
# Collecting 2009 ...
# Finished 2009 (22000 movies total so far)
# Collecting 2010 ...
# Finished 2010 (22200 movies total so far)
# Collecting 2011 ...
# Finished 2011 (22400 movies total so far)
# Collecting 2012 ...
# Finished 2012 (22600 movies total so far)
# Collecting 2013 ...
# Finished 2013 (22800 movies total so far)
# Collecting 2014 ...
# Finished 2014 (23000 movies total so far)
# Collecting 2015 ...
# Finished 2015 (23200 movies total so far)
# Collecting 2016 ...
# Finished 2016 (23400 movies total so far)
# Collecting 2017 ...
# Finished 2017 (23600 movies total so far)
# Collecting 2018 ...
# Finished 2018 (23800 movies total so far)
# Collecting 2019 ...
# Finished 2019 (24000 movies total so far)
# Collecting 2020 ...
# Finished 2020 (24200 movies total so far)
# Collecting 2021 ...
# Finished 2021 (24400 movies total so far)
# Collecting 2022 ...
# Finished 2022 (24600 movies total so far)
# Collecting 2023 ...
# Finished 2023 (24800 movies total so far)
# Collecting 2024 ...
# Finished 2024 (25000 movies total so far)
# Collecting 2025 ...
# Finished 2025 (25200 movies total so far)
# Saved 25200 movies from 1900–2025
